# %%
import pyreadstat
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_spss(R'identity.sav')

# %%
#无序类别变量的描述统计
df['政治面貌'].value_counts(normalize=True)
# Out:
# 政治面貌
# 团员    0.734104
# 党员    0.130636
# 群众    0.110983
# 其他    0.024277
# Name: proportion, dtype: float64

# %%
# 生成x、y轴方向的坐标
x = df['政治面貌'].value_counts().index
y = df['政治面貌'].value_counts(normalize=True).values * 100
# 创建图
fig, ax = plt.subplots()
# 绘制柱状图
rects1 = ax.bar(x, y)
# 设置x轴变量名称
ax.set_xlabel('政治面貌')
# 设置y轴最大值
ax.set_ylim(ymax=100)
# 在柱上方显示对应的值
ax.bar_label(rects1, fmt="%.1f", padding=3)
# 显示图形
plt.show()
# Out:
# C:\Users\北柠\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 22242 (\N{CJK UNIFIED IDEOGRAPH-56E2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\北柠\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21592 (\N{CJK UNIFIED IDEOGRAPH-5458}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\北柠\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20826 (\N{CJK UNIFIED IDEOGRAPH-515A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\北柠\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 32676 (\N{CJK UNIFIED IDEOGRAPH-7FA4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\北柠\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20247 (\N{CJK UNIFIED IDEOGRAPH-4F17}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\北柠\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20854 (\N{CJK UNIFIED IDEOGRAPH-5176}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\北柠\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20182 (\N{CJK UNIFIED IDEOGRAPH-4ED6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\北柠\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 25919 (\N{CJK UNIFIED IDEOGRAPH-653F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\北柠\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 27835 (\N{CJK UNIFIED IDEOGRAPH-6CBB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\北柠\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 38754 (\N{CJK UNIFIED IDEOGRAPH-9762}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\北柠\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 35980 (\N{CJK UNIFIED IDEOGRAPH-8C8C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import mytools
mytools.读取SPSS数据(R'identity.sav')
mytools.绘制单个类别变量柱状图
# Out:
# <function mytools.绘制单个类别变量柱状图(数据表, 变量: str)>

# %%
import mytools
df2,meta=mytools.读取SPSS数据(R'identity.sav')
mytools.绘制单个类别变量柱状图(df2,'年级')

# %%
import matplotlib.pyplot as plt  
  
# 数据  
categories = ['Category1', 'Category2', 'Category3', 'Category4']  
values = [10, 15, 7, 12]  
  
# 创建柱状图  
plt.bar(categories, values)  
  
# 设置标题和标签  
plt.title('柱状图')  
plt.xlabel('类别')  
plt.ylabel('值')  
  
# 显示图形  
plt.show()

# %%
import matplotlib.pyplot as plt  
  
# 数据  
labels = ['数据表', '变量', ]  
sizes = [15, 30, ]  
  
# 创建饼状图  
plt.pie(sizes, labels=labels, autopct='%1.1f%%')  
  
# 确保饼图是圆的  
plt.axis('equal')    
  
# 显示图形  
plt.show()
