# %%
import matplotlib.pyplot as plt
plt.rcParams["font.sans-serif"]=["SimHei"]#设置字体
plt.rcParams["figure.figsize"]=(6.4,4.8)#设置大小，默认为英寸
plt.rcParams["axes.unicode_minus"]=False #该语句解决图像中的“-”负号的乱码问题

# %%
x=[1,2,3,4]
y=[1,4,2,3]

# %%
fig,ax=plt.subplots()
ax.plot(x,y)

# %%
fig,ax=plt.subplots()
ax.plot(x,y)
ax.set_xlabel('变量a')
ax.set_ylabel('entryb')
plt.show()
# Out:
# C:\Users\北柠\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\北柠\AppData\Roaming\Python\Python38\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 37327 (\N{CJK UNIFIED IDEOGRAPH-91CF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
